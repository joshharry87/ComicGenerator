# %% [markdown]
# ## Segmentation modelling Notebook
#
# Identify pivot, rotation, anchor and scale of rotation points in 2d Images for frame to frame animation

# %%
import numpy as np
import scipy as sci
import sklearn as skle
