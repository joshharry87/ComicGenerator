# %% [markdown]
# Image Preprocessing - Scene Creation etc.
#
# https://markaicode.com/6-python-image-processing-libraries-for-advanced-visual-manipulation/
#
# libs : openCV, skimage  and PIL
#
# from skimage import io, filters, measure, segmentation
# import matplotlib.pyplot as plt

# %%
from skimage import io, filters, measure, segmentation
import matplotlib.pyplot as plt

from PIL import Image, ImageFilter, ImageEnhance
import cv2
import numpy as np


import sys 
import os


print(sys.path)
# Out:
# ['c:\\repos\\ComicGen\\ComicGenerator\\ComicAssets\\RawPhotos\\PublicDomainPhotos', 'c:\\Users\\joshc\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'c:\\Users\\joshc\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'c:\\Users\\joshc\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'c:\\Users\\joshc\\AppData\\Local\\Programs\\Python\\Python311', '', 'C:\\Users\\joshc\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\joshc\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\joshc\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\joshc\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\joshc\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages']

# %%
filePaths = {}
for folder,file, dir in os.walk(os.curdir):
    directories = []
    for filepath in dir:
        directories.append(folder + f'\{filepath}' )
    filePaths[folder[2:]] = directories

# %%
filePaths
# Out:
# {'': ['.\\ImageProcessing.ipynb'],
#  'Asia': ['.\\Asia\\.jpeg',
#   '.\\Asia\\ASIA_BuildingExteriot.jpeg',
#   '.\\Asia\\ASIA_Street.jpeg',
#   '.\\Asia\\JAP_BuildingExterior.jpg',
#   '.\\Asia\\JAP_Street.jpeg',
#   '.\\Asia\\JAP_StreetWide.jpg'],
#  'Aus': ['.\\Aus\\Australian_Senate_-_Parliament_of_Australia.jpg',
#   '.\\Aus\\Aus_LibraryInterior.jpg',
#   '.\\Aus\\AUS_SupremeCourt.jpg',
#   '.\\Aus\\b8130d01a917dfcd393fc27bc616dac5.jpg',
#   '.\\Aus\\cityscape-street-sunny-day-urban-preview.jpg',
#   '.\\Aus\\Corroboree_Park,_Ainslie,_Australian_Capital_Territory.JPG',
#   '.\\Aus\\czNmcy1wcml2YXRlL3Jhd3BpeGVsX2ltYWdlcy93ZWJzaXRlX2NvbnRlbnQvbHIvZnJhcmNoaXRlY3R1cmVfYXR0cmFjdGlvbl9hdXN0cmFsaWFfOTMxMDcwLWltYWdlLWt5Y2k5ZDNkLmpwZw.jpg',
#   '.\\Aus\\Hobart-Tasmania-Australia04.jpg',
#   '.\\Aus\\Royal_Australasian_College_of_Surgeons,_Melbourne_Australia_(4557539616).jpg',
#   '.\\Aus\\The_interior_of_a_modern_elementary_school.jpg'],
#  'China': ['.\\China\\CHINA_Government.jpg', '.\\China\\CHINA_Street.jpg'],
#  'Europe': ['.\\Europe\\EU_EuropeanUnionBuilding.jpg',
#   '.\\Europe\\EU_EuropeanUnionBuildingF.jpg',
#   '.\\Europe\\EU_St2.jpg',
#   '.\\Europe\\EU_St3.jpg',
#   '.\\Europe\\EU_StI.jpg'],
#  'GlobalStructures': ['.\\GlobalStructures\\UN_AssemblyInt.jpeg',
#   '.\\GlobalStructures\\UN_FlagsExterior.jpeg',
#   '.\\GlobalStructures\\WHO_Exterior.jpg',
#   '.\\GlobalStructures\\WHO_Interior.jpg',
#   '.\\GlobalStructures\\WorldBank.jpg'],
#  'India': ['.\\India\\Ind_st.jpg', '.\\India\\Ind_st2.jpg'],
#  'Interiors': ['.\\Interiors\\GenericInterior.jpg'],
#  'LatinAmerica': ['.\\LatinAmerica\\LatinUSA_St3.jpg',
#   '.\\LatinAmerica\\LatinUS_govBuilding.jpg',
#   '.\\LatinAmerica\\LatinUS_GovBuilding2.jpeg',
#   '.\\LatinAmerica\\LatinUS_St.jpg',
#   '.\\LatinAmerica\\LatinUS_St2.jpg',
#   '.\\LatinAmerica\\Miraflores_Palace_Venezuela.png'],
#  'Mediterannean': ['.\\Mediterannean\\MED_ext.jpg',
#   '.\\Mediterannean\\Med_st.jpg',
#   '.\\Mediterannean\\Med_St2..jpg',
#   '.\\Mediterannean\\Med_St3.jpeg'],
#  'Russia': ['.\\Russia\\RUS_School.jpeg', '.\\Russia\\RUS_Street.jpeg'],
#  'UAE': ['.\\UAE\\Azerbaijani-UAE_documents_were_signed,_2016_01.jpg',
#   '.\\UAE\\UAE.jpeg',
#   '.\\UAE\\uaepark.jpg',
#   '.\\UAE\\uaestreet.jpeg'],
#  'UK': ['.\\UK\\brick-street-with-graffiti.jpg',
#   '.\\UK\\Houses_of_Parliament,_London_(7654658782).jpg',
#   '.\\UK\\UK_Street.jpeg'],
#  'US': ['.\\US\\negative-space-nyc-street-background-1062x681.jpg',
#   '.\\US\\pexels-michael-d-beckwith-2150568551-31282456.jpg',
#   '.\\US\\senate-1-1170x778-1-800x400.jpg',
#   '.\\US\\USA_CourtExterior.jpg',
#   '.\\US\\US_Congress_02.jpg',
#   '.\\US\\whitehouseusa.jpg']}

# %%
testImage = cv2.imread(filePaths['Asia'][3])

# %%
type(testImage)
testImage

gray_image = cv2.cvtColor(testImage, cv2.COLOR_BGR2GRAY) 

cv2.imshow('Original',gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('Original',testImage)
